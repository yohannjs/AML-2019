# %% [markdown]
# <b>AML2019</b>

# %% [markdown]
# ### Useful links
#
# - [Lin reg on Boston Housing dataset](https://towardsdatascience.com/linear-regression-on-boston-housing-dataset-f409b7e4a155)
# - [Lin reg in sckit learn](https://bigdata-madesimple.com/how-to-run-linear-regression-in-python-scikit-learn/)
# - [Train test split and cross validation](https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6)
# - [Ridge and Lasso regression](https://towardsdatascience.com/ridge-and-lasso-regression-a-complete-guide-with-python-scikit-learn-e20e34bcbf0b)
# - [Best article in Boston House Pricing](https://gogul09.github.io/software/regression-example-boston-housing-prices)

# %%
from tqdm import tqdm # running time
import warnings
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 
import seaborn as sns # plotting
from scipy import stats
from matplotlib import pyplot as plt # plots 

from sklearn.metrics import mean_squared_error
from sklearn.metrics.scorer import make_scorer

# display
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
traindataset = pd.read_csv("challenge_data/train.csv")
realtraindataset = pd.read_csv("challenge_data/clean_train_data.csv")
realtestdataset = pd.read_csv("challenge_data/clean_test_data.csv")

print("Original dataset")
print("Rows in dataset: ", traindataset.shape[0])
print("Colums in dataset: ",traindataset.shape[1])


print("One-hot encoded dataset" )
print("Rows in dataset: ", realtraindataset.shape[0])
print("Colums in dataset: ", realtraindataset.shape[1])

print("added " + str(realtraindataset.shape[1] - traindataset.shape[1])+ " columns with one-hot encoding")

print("Test dataset")
print("Rows in dataset: ", realtestdataset.shape[0])
print("Colums in dataset: ", realtestdataset.shape[1])
# Out:
# Original dataset
# Rows in dataset:  1200
# Colums in dataset:  81
# One-hot encoded dataset
# Rows in dataset:  1200
# Colums in dataset:  253
# added 172 columns with one-hot encoding
# Test dataset
# Rows in dataset:  260
# Colums in dataset:  252

# %%
plt.figure(figsize=(15,10))

plt.subplot(121)
stats.probplot(realtraindataset.SalePrice, plot=plt)
plt.grid()

plt.subplot(122)
stats.probplot(np.log(realtraindataset.SalePrice), plot=plt)
plt.grid()

# %%
y = np.log(realtraindataset['SalePrice'])  # copies SalePrice to a new dataframe and make it Gaussian distrubuted
X = realtraindataset.drop(['LotFrontage', 'MasVnrArea','GarageYrBlt', 'SalePrice'], axis=1) # drops SalePrice from the training data. Also dropping LotFrontage and GarageYrBlt as they contain null values


print("Null values in dataset: ", X.isnull().sum().any()) # checks for null values
print(y.shape)
print(X.shape)
# allnum_prices = allnum_train['SalePrice'].copy()
# Out:
# Null values in dataset:  False
# (1200,)
# (1200, 249)

# %% [markdown]
# Feature engineering

# %%
X['TotalSquareFeet'] = X['TotalBsmtSF'] + X['1stFlrSF'] + X['2ndFlrSF']
X = X.drop(['TotalBsmtSF','1stFlrSF','2ndFlrSF'], axis=1) # drops old features

# %% [markdown]
# Functions used for hyperparameter optimazation selection

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure(figsize=(15,10))
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    plt.legend(loc="best")
    
    return plt
    
    
print("ok")
# Out:
# ok

# %%
from sklearn.model_selection import train_test_split

# Divide training set 

seed = 10
test_size = 0.20

#X_train, X_test, Y_train, Y_test  = train_test_split(allnum_train, allnum_prices, test_size = test_size, random_state = seed)

X_train, X_test, Y_train, Y_test  = train_test_split(X, y, test_size = test_size, random_state = seed)


print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (960, 247)
# (240, 247)
# (960,)
# (240,)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error

#scoring function
def scoring_func(guess, predictions):
    difference = np.sqrt(mean_squared_error(guess,predictions))
    return difference

custom_scorer = make_scorer(scoring_func,greater_is_better=True)

# user variables to tune
folds   = 10
metric = "mean_squared_error"

# hold different regression models in a single dictionary
models = {}
models["Linear"]        = LinearRegression()
models["Lasso"]         = Lasso()
models["ElasticNet"]    = ElasticNet()
models["KNN"]           = KNeighborsRegressor()
models["DecisionTree"]  = DecisionTreeRegressor()
models["SVR"]           = SVR()
models["AdaBoost"]      = AdaBoostRegressor()
models["GradientBoost"] = GradientBoostingRegressor()
models["RandomForest"]  = RandomForestRegressor()
models["ExtraTrees"]    = ExtraTreesRegressor()

# 10-fold cross validation for each model
model_results = pd.DataFrame(columns=['ModelName', 'Mean', 'StandardDeviation'])
i = 0
for model_name in models:
    model   = models[model_name]
    k_fold  = KFold(n_splits=folds, random_state=seed)
    results = cross_val_score(model, X_train, Y_train, cv=k_fold, scoring=custom_scorer)
    #results = cross_val_score(model, X_train, Y_train, cv=k_fold, scoring=metric)
    model_results.loc[i] = [model_name, round(results.mean(), 3), round(results.std(), 3)]
    i += 1


# box-whisker plot to compare regression models
'''figure = plt.figure()
figure.suptitle('Regression models comparison')
axis = figure.add_subplot(111)
plt.boxplot(model_results.Series.values)
axis.set_xticklabels(model_names, rotation = 45, ha="right")
axis.set_ylabel("Mean Squared Error (MSE)")
plt.margins(0.05, 0.1)
plt.show()'''

model_results.head(10)
# Out:
#        ModelName      Mean  StandardDeviation
# 0   DecisionTree     0.230              0.032
# 1            KNN     0.239              0.022
# 2  GradientBoost     0.134              0.026
# 3     ElasticNet     0.174              0.037
# 4   RandomForest     0.158              0.026
# 5     ExtraTrees     0.153              0.027
# 6            SVR     0.406              0.034
# 7       AdaBoost     0.178              0.017
# 8         Linear  4266.232           6740.477
# 9          Lasso     0.181              0.040

# %% [markdown]
# GradientBoost is the best model. We will use hyperparameter optimazaton on the model to further strengthen our prediction

# %%
# Best model 
best_model = GradientBoostingRegressor()
best_model.fit(X_train,Y_train)

best_predictions = best_model.predict(X_test)
print("[INFO] MSE : {}".format(round(mean_squared_error(best_predictions, Y_test), 3)))

plt.figure(figsize=(15,10))
plt.scatter(best_predictions, Y_test, alpha=0.6, c='g')
plt.plot([11,13.5],[11,13.5],"r")
plt.xlabel("Predicted price")
plt.ylabel("Actual price")
plt.title("Gradient Boosting Regressor")
plt.show()
# Out:
# [INFO] MSE : 0.014

# %%
plot_learning_curve(best_model, "Gradient Boosting Regressor without hyperparameter optimazation", X, y, cv=10, n_jobs = 4)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py'>

# %%
from sklearn.grid_search import GridSearchCV

def hyperparameterOpt(estimator, params, cv, n_jobs=4):
    model_to_estimate = GridSearchCV(estimator = estimator, param_grid = params, cv = cv, n_jobs = n_jobs, verbose = 10)
    model_to_estimate.fit(X_train, Y_train)
    print("Best parameters from GridSearchCV: ", model.best_estimator_)
    return model_to_estimate.best_estimator_

param_grid = {'n_estimators':[100, 500, 1000],
              'learning_rate': [0.1, 0.05, 0.02],
              'max_depth':[4,6],
              'min_samples_leaf':[3,5,9], 
              'max_features':[1.0,0.3]
             }

model = GradientBoostingRegressor()
best_parameters = hyperparameterOpt(model, param_grid, cv = 10)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.803046 -   0.9s
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.916357 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.914022 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.900920 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.897935 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.888289 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.831891 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.877660 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    1.8s
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.918214 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=100, score=0.870041 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    2.7s
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.794773 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.908984 -   3.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.921479 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.909169 -   3.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.888153 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.828563 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.880234 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.874872 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:   10.1s
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.922373 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=500, score=0.875464 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.791177 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.909242 -   7.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.908960 -   7.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.922511 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:   20.6s
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.888359 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.825189 -   7.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.879528 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.874455 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.802255 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.909857 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.916806 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.910837 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.887958 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.843983 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:   30.4s
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.885829 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.878889 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.914727 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=100, score=0.875310 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.921512 -   7.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=1.0, n_estimators=1000, score=0.874505 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.793827 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.915177 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.908024 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   36.0s
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.912200 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.880665 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.834284 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.885033 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.878663 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.913395 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=500, score=0.879416 -   3.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.792705 -   7.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.915780 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.911975 -   7.2s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.906907 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:   50.5s
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.879209 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.832039 -   7.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.883711 -   7.0s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.876278 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.819408 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.909719 -   0.9s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.922172 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.914956 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.896082 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.842333 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  1.0min
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.887556 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.878904 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.907985 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.911611 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=100, score=0.864940 -   0.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=1.0, n_estimators=1000, score=0.878467 -   7.4s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.819767 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.906215 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.917317 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.918638 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.895666 -   3.5s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.833653 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.885393 -   3.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.869454 -   3.5s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:  1.2min
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.909941 -   3.5s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=500, score=0.861709 -   3.5s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.819972 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.904717 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.916799 -   7.1s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.918940 -   7.0s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.893566 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.830488 -   7.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.867397 -   6.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.883745 -   7.1s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.816049 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.890256 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:  1.4min
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.914961 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.920468 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.891728 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.835121 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.903171 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.872345 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.912087 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=100, score=0.876604 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.811202 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.912574 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.922954 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.918119 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.907830 -   7.2s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=1.0, n_estimators=1000, score=0.861922 -   7.1s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.892103 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.835526 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500
# [Parallel(n_jobs=4)]: Done 105 tasks      | elapsed:  1.5min
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.900682 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.887116 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.920153 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=500, score=0.908082 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.809551 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.913556 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.919050 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.921230 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.891734 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.835808 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.890544 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.893932 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.837038 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.922447 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.916029 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:  1.7min
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.920105 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.899923 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.846706 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.914971 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.889587 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.902030 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=100, score=0.889938 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.911396 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=4, max_features=0.3, n_estimators=1000, score=0.904435 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.822363 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.920615 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.924075 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.915282 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.894701 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.836779 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.904524 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [Parallel(n_jobs=4)]: Done 137 tasks      | elapsed:  1.7min
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.879190 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.921423 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=500, score=0.886286 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.821277 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.908269 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.928803 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.923644 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.887092 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.842687 -   2.9s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.887174 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.880131 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.807683 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.916819 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.931866 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.919842 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.898963 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.848026 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.897043 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  1.9min
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.888780 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.928544 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=100, score=0.891910 -   0.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.907487 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=4, max_features=0.3, n_estimators=1000, score=0.893465 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.814121 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.919187 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.914199 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.925189 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.903018 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.840341 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.901772 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.879013 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.927018 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=500, score=0.876311 -   1.3s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.808989 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.916808 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.919565 -   2.6s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.926601 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [Parallel(n_jobs=4)]: Done 173 tasks      | elapsed:  2.0min
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.887284 -   2.8s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.836146 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.884660 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.868229 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.787839 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.892776 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.908789 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=9, max_depth=4, max_features=0.3, n_estimators=1000, score=0.886822 -   2.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.899227 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.883757 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.890580 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.849155 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.867055 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.876465 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.848542 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=100, score=0.887515 -   1.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.892116 -   6.3s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.788709 -   6.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:  2.2min
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.896364 -   6.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.886533 -   6.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.887591 -   6.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.846119 -   6.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.871501 -   6.4s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.875186 -   6.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.877570 -   6.5s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=500, score=0.849092 -   6.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.788229 -   8.7s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.893014 -   9.0s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.893797 -   8.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.886521 -   8.8s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.844189 -   8.1s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.888432 -   8.6s
# [CV] learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.863188 -   8.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.875724 -   8.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.784252 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.899457 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.882661 -   8.6s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.907731 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.908198 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=3, max_depth=6, max_features=1.0, n_estimators=1000, score=0.850316 -   8.8s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [Parallel(n_jobs=4)]: Done 213 tasks      | elapsed:  2.8min
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.893222 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.848597 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.886678 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.863219 -   1.5s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.909782 -   1.4s
# [CV] learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=500
# [CV]  learning_rate=0.1, min_samples_leaf=5, max_depth=6, max_features=1.0, n_estimators=100, score=0.854228 -   1.5s
# ...
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=500, score=0.914784 -   2.8s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=500, score=0.898207 -   2.9s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.818053 -   4.8s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.902407 -   5.0s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.922871 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.926081 -   5.0s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.894654 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.855530 -   5.0s
# [CV] learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.902278 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.881020 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.760721 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.848023 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.877401 -   0.8s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.885251 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.872671 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.842762 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.861650 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.844228 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.882150 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.918869 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=100, score=0.864465 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=3, max_depth=6, max_features=0.3, n_estimators=1000, score=0.902284 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.818362 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.912301 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.925390 -   2.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.920648 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.897384 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.853856 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.899854 -   2.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.883752 -   2.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.920510 -   2.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=500, score=0.898854 -   2.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.812935 -   4.9s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.916518 -   4.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.922228 -   4.7s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.925808 -   4.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.896763 -   4.8s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.857502 -   4.6s
# [CV] learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.884305 -   4.5s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.901282 -   4.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.765127 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.853245 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [Parallel(n_jobs=4)]: Done 1050 tasks      | elapsed: 16.3min
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.876224 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.880004 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.873701 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.844016 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.853991 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.898682 -   4.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100
# [CV]  learning_rate=0.02, min_samples_leaf=5, max_depth=6, max_features=0.3, n_estimators=1000, score=0.921051 -   4.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.839615 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.876018 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=100, score=0.871459 -   0.7s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.915600 -   2.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.813426 -   2.4s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.925586 -   2.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.924665 -   2.2s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.899499 -   2.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.856199 -   2.4s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.900037 -   2.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.887796 -   2.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.915571 -   2.4s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=500, score=0.888694 -   2.5s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.918292 -   4.0s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.815302 -   4.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.926814 -   4.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.924266 -   4.2s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.902067 -   4.2s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.858890 -   4.3s
# [CV] learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.905360 -   4.2s
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.888093 -   4.2s
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.922696 -   4.1s
# [CV]  learning_rate=0.02, min_samples_leaf=9, max_depth=6, max_features=0.3, n_estimators=1000, score=0.903637 -   4.2s
# [Parallel(n_jobs=4)]: Done 1080 out of 1080 | elapsed: 16.6min finished
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-8fa6cbf82ad4> in <module>()
#      15
#      16 model = GradientBoostingRegressor()
# ---> 17 best_parameters = hyperparameterOpt(model, param_grid, cv = 10)
#
# <ipython-input-83-8fa6cbf82ad4> in hyperparameterOpt(estimator, params, cv, n_jobs)
#       4     model_to_estimate = GridSearchCV(estimator = estimator, param_grid = params, cv = cv, n_jobs = n_jobs, verbose = 10)
#       5     model_to_estimate.fit(X_train, Y_train)
# ----> 6     print("Best parameters from GridSearchCV: ", model.best_estimator_)
#       7     return model.best_estimator_
#       8
#
# AttributeError: 'GradientBoostingRegressor' object has no attribute 'best_estimator_'
